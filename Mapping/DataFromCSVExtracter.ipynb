# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'All Project Registrations - 2012 -2018.xlsx',
#  'dms2dec.py',
#  'GetData.py',
#  'Map1.html',
#  'MapGenerator.py',
#  'MapMarked.html',
#  'ProjList.csv',
#  'Untitled.ipynb']

# %%
import pandas

# %%
POI1 = pandas.read_csv("ProjList.csv", error_bad_lines=False, delimiter=";")
POI1
# Out:
#     Project No                 Tender No  \
# 0       MH0083                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4          NaN                       NaN
# 5          NaN                       NaN
# 6       LE0032                       NaN
# 7       PN0085                       NaN
# 8       MH0106                   XM14041
# 9          NaN                       NaN
# 10         NaN                       NaN
# 11         NaN                       NaN
# 12         NaN                       NaN
# 13         NaN                       NaN
# 14         NaN                       NaN
# 15      MH0070                       NaN
# 16      MH0095                Ref MH0081
# 17     MHA0001                   XH14052
# 18      PG0027                  XGE17066
# 19      MH0129                  XME17089
# 20      MH0128                  XRE17071
# 21      PN0040                   XN12081
# ...
